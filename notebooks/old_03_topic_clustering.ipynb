# %% [markdown]
# # Topic modelling and clustering

# %%
import sys
sys.path.append("..")

from src.parallel_vectorizer_tokenizer import *

import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# %%
vectors, vec = FastTfIdfVectorizer.load_vectors_vectorizer()
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
numTopics = 10
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(vectors.shape)
# Out:
# (30000, 149830)
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from sklearn.decomposition import LatentDirichletAllocation

alpha = 50/numTopics
beta = 0.1

lda_model = LatentDirichletAllocation(n_components = numTopics, 
                                doc_topic_prior= alpha, 
                                topic_word_prior = beta, 
                                random_state=0)

lda_output = lda_model.fit_transform(vectors)
panel = pyLDAvis.sklearn.prepare(lda_model, vectors, vec)
panel
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 7      0.025373 -0.016082       1        1  10.007096
# 5      0.056086  0.000098       2        1  10.006880
# 1     -0.012092 -0.024873       3        1  10.001782
# 2     -0.029889  0.005764       4        1  10.000843
# 3     -0.006876 -0.010817       5        1  10.000086
# 8     -0.024988  0.008077       6        1   9.999235
# 9     -0.003215  0.050811       7        1   9.998133
# 6     -0.010129 -0.033901       8        1   9.996563
# 0      0.007752  0.026995       9        1   9.996290
# 4     -0.002022 -0.006072      10        1   9.993093, topic_info=              Term        Freq       Total Category  logprob  loglift
# 113033  relatively    6.000000    6.000000  Default  30.0000  30.0000
# 4871            3d  439.000000  439.000000  Default  29.0000  29.0000
# 26230       cancer    8.000000    8.000000  Default  28.0000  28.0000
# 106306       pratt    8.000000    8.000000  Default  27.0000  27.0000
# 146168      willie    7.000000    7.000000  Default  26.0000  26.0000
# ...            ...         ...         ...      ...      ...      ...
# 101113       party   21.959916  177.025070  Topic10  -7.3239   0.2162
# 91277       motion   28.971657  352.626346  Topic10  -7.0468  -0.1958
# 98376      opinion   26.106888  283.227642  Topic10  -7.1509  -0.0808
# 145426     whether   24.289718  248.500246  Topic10  -7.2231  -0.0221
# 98589        order   24.651437  298.778716  Topic10  -7.2083  -0.1916
#
# [858 rows x 6 columns], token_table=        Topic      Freq     Term
# term
# 345         1  0.099174        1
# 345         2  0.090159        1
# 345         3  0.063111        1
# 345         4  0.112698        1
# 345         5  0.081143        1
# ...       ...       ...      ...
# 148229      9  0.088244    years
# 148229     10  0.111776    years
# 148266      6  0.813569  yelling
# 148532      2  0.958296  younger
# 149225      9  0.943337     zion
#
# [1616 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[8, 6, 2, 3, 4, 9, 10, 7, 1, 5])

# %% [markdown]
# ### Gensim LSI

# %%
from gensim.test.utils import common_dictionary, common_corpus
from gensim.models import LsiModel
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
reverse_vocabulary = { vec.vocabulary_[k]:k for k in vec.vocabulary_}
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model = LsiModel(vectors.transpose(), id2word=reverse_vocabulary, num_topics=numTopics)
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#vectorized_corpus = model[vectors]  
#print(vectorized_corpus)
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
topics = model.get_topics()
topics.shape
# Out:
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (10, 149830)

# %%
topWords = []
for topicno in range(numTopics):
    print('Topic {}'.format(topicno))
    print([(x, round(y, 2)) for x, y in model.show_topic(topicno, topn=50)], '\n')
    topWords.append([(x) for x, y in model.show_topic(topicno, topn=50)])
print(set.intersection(*map(set,topWords)))
# Out:
# Topic 0
# [('evidence', 0.15), ('app', 0.13), ('3d', 0.13), ('jury', 0.13), ('section', 0.12), ('would', 0.1), ('motion', 0.1), ('arrest', 0.09), ('robbery', 0.09), ('time', 0.08), ('may', 0.08), ('petition', 0.08), ('order', 0.08), ('statute', 0.08), ('error', 0.08), ('respondent', 0.07), ('one', 0.07), ('appeal', 0.07), ('testimony', 0.07), ('gun', 0.07), ('testified', 0.07), ('also', 0.07), ('whether', 0.07), ('hearing', 0.07), ('police', 0.07), ('filed', 0.07), ('county', 0.07), ('rule', 0.07), ('record', 0.07), ('right', 0.07), ('cause', 0.07), ('west', 0.06), ('1', 0.06), ('could', 0.06), ('must', 0.06), ('circuit', 0.06), ('ilcs', 0.06), ('see', 0.06), ('2', 0.06), ('city', 0.06), ('attorney', 0.06), ('complaint', 0.06), ('illinois', 0.06), ('shall', 0.06), ('question', 0.06), ('board', 0.06), ('officer', 0.06), ('issue', 0.06), ('first', 0.06), ('defense', 0.06)]
#
# Topic 1
# [('robbery', 0.31), ('gun', 0.25), ('arrest', 0.25), ('decree', -0.15), ('weapon', 0.14), ('police', 0.14), ('deed', -0.13), ('bill', -0.13), ('land', -0.11), ('murder', 0.1), ('officer', 0.1), ('victim', 0.1), ('cocaine', 0.1), ('sale', -0.1), ('title', -0.1), ('offense', 0.09), ('armed', 0.09), ('testified', 0.09), ('estate', -0.09), ('gang', 0.09), ('company', -0.08), ('firearm', 0.08), ('mortgage', -0.08), ('car', 0.08), ('3d', 0.08), ('conviction', 0.08), ('criminal', 0.07), ('interest', -0.07), ('paid', -0.07), ('sentencing', 0.07), ('payment', -0.07), ('app', 0.07), ('jury', 0.07), ('guilty', 0.07), ('city', -0.07), ('testimony', 0.06), ('shall', -0.06), ('knife', 0.06), ('tax', -0.06), ('suit', -0.06), ('drugs', 0.06), ('amount', -0.06), ('crime', 0.06), ('pay', -0.06), ('lien', -0.06), ('premises', -0.06), ('appellants', -0.06), ('parties', -0.06), ('aggravated', 0.06), ('county', -0.06)]
#
# Topic 2
# [('respondent', -0.32), ('jury', 0.19), ('section', -0.16), ('robbery', 0.15), ('gun', 0.15), ('petition', -0.15), ('evidence', 0.14), ('3d', -0.14), ('app', -0.13), ('petitioner', -0.13), ('arrest', 0.12), ('claimant', -0.12), ('instruction', 0.12), ('ilcs', -0.11), ('deed', 0.11), ('error', 0.11), ('bill', 0.1), ('decree', 0.1), ('board', -0.1), ('order', -0.09), ('west', -0.09), ('land', 0.09), ('verdict', 0.09), ('child', -0.08), ('complaint', -0.08), ('car', 0.08), ('motion', -0.07), ('code', -0.07), ('hearing', -0.07), ('title', 0.07), ('commission', -0.07), ('testimony', 0.07), ('instructions', 0.07), ('sale', 0.07), ('2', -0.06), ('complainant', 0.06), ('weapon', 0.06), ('witness', 0.06), ('company', 0.06), ('filed', -0.06), ('illinois', -0.06), ('possession', 0.06), ('mortgage', 0.06), ('1998', -0.06), ('department', -0.06), ('money', 0.06), ('appeal', -0.06), ('1996', -0.06), ('railroad', 0.06), ('street', 0.06)]
#
# Topic 3
# [('robbery', -0.27), ('respondent', -0.22), ('decree', -0.2), ('claimant', 0.2), ('jury', 0.19), ('deed', -0.18), ('negligence', 0.15), ('instruction', 0.14), ('bill', -0.14), ('injury', 0.13), ('gun', -0.12), ('train', 0.11), ('policy', 0.11), ('accident', 0.11), ('petition', -0.11), ('sale', -0.11), ('title', -0.11), ('city', 0.11), ('mortgage', -0.1), ('petitioner', -0.1), ('damages', 0.1), ('verdict', 0.1), ('insurance', 0.1), ('car', 0.1), ('weapon', -0.1), ('complainant', -0.09), ('evidence', 0.09), ('estate', -0.09), ('company', 0.08), ('railroad', 0.08), ('street', 0.08), ('land', -0.08), ('care', 0.08), ('instructions', 0.08), ('track', 0.08), ('duty', 0.07), ('armed', -0.07), ('coverage', 0.07), ('ordinance', 0.07), ('arrest', -0.07), ('interest', -0.07), ('insured', 0.06), ('possession', -0.06), ('liability', 0.06), ('injuries', 0.06), ('firearm', -0.06), ('complaint', 0.06), ('work', 0.06), ('crossing', 0.06), ('plea', -0.06)]
#
# Topic 4
# [('respondent', 0.63), ('claimant', 0.27), ('evidence', 0.15), ('petitioner', 0.15), ('jury', 0.14), ('section', -0.13), ('child', 0.12), ('board', -0.1), ('instruction', 0.1), ('arrest', -0.1), ('city', -0.1), ('children', 0.09), ('ordinance', -0.09), ('complaint', -0.09), ('robbery', -0.08), ('testified', 0.08), ('testimony', 0.08), ('policy', -0.08), ('statute', -0.08), ('marriage', 0.07), ('tax', -0.07), ('verdict', 0.07), ('insurance', -0.07), ('code', -0.07), ('county', -0.06), ('public', -0.06), ('motion', -0.06), ('district', -0.06), ('instructions', 0.06), ('train', 0.05), ('care', 0.05), ('witness', 0.05), ('parental', 0.05), ('commission', 0.05), ('3d', -0.05), ('app', -0.05), ('coverage', -0.05), ('mother', 0.05), ('parent', 0.05), ('negligence', 0.05), ('ilcs', -0.05), ('car', 0.05), ('custody', 0.05), ('appeal', -0.04), ('legislature', -0.04), ('west', -0.04), ('weapon', -0.04), ('father', 0.04), ('error', 0.04), ('plea', -0.04)]
#
# Topic 5
# [('arrest', 0.64), ('robbery', -0.36), ('cocaine', 0.23), ('officer', 0.2), ('police', 0.16), ('jury', -0.15), ('search', 0.14), ('narcotics', 0.11), ('officers', 0.11), ('plea', -0.1), ('claimant', 0.1), ('armed', -0.09), ('drugs', 0.09), ('cannabis', 0.08), ('warrant', 0.08), ('murder', -0.08), ('guilty', -0.08), ('sentencing', -0.07), ('probable', 0.07), ('respondent', 0.07), ('instruction', -0.07), ('suppress', 0.07), ('weapon', -0.07), ('firearm', -0.06), ('gun', -0.06), ('vehicle', 0.06), ('verdict', -0.05), ('stop', 0.05), ('aggravated', -0.05), ('sentences', -0.05), ('victim', -0.05), ('marijuana', 0.05), ('offense', -0.05), ('possession', 0.05), ('deed', 0.05), ('death', -0.04), ('arrested', 0.04), ('conviction', -0.04), ('error', -0.04), ('instructions', -0.04), ('heroin', 0.04), ('car', 0.04), ('informant', 0.04), ('felony', -0.04), ('petition', -0.04), ('investigation', 0.04), ('license', 0.04), ('knife', -0.04), ('sexual', -0.04), ('seizure', 0.04)]
#
# Topic 6
# [('claimant', -0.59), ('robbery', -0.3), ('gun', -0.25), ('jury', 0.18), ('weapon', -0.16), ('commission', -0.14), ('plea', 0.13), ('motion', 0.11), ('petition', 0.11), ('firearm', -0.09), ('instruction', 0.09), ('employer', -0.09), ('policy', -0.08), ('compensation', -0.08), ('verdict', 0.08), ('armed', -0.08), ('insurance', -0.08), ('cocaine', 0.08), ('industrial', -0.08), ('guilty', 0.08), ('deed', -0.08), ('error', 0.08), ('evidence', 0.07), ('judge', 0.06), ('arbitrator', -0.06), ('appeal', 0.06), ('work', -0.06), ('employment', -0.06), ('board', -0.06), ('benefits', -0.06), ('published', 0.06), ('claimants', -0.06), ('employee', -0.06), ('justice', 0.06), ('tax', -0.06), ('instructions', 0.06), ('land', -0.06), ('arrest', 0.05), ('child', 0.05), ('coverage', -0.05), ('opinion', 0.05), ('title', -0.05), ('rule', 0.05), ('comm', -0.05), ('city', -0.05), ('petitioner', 0.05), ('gang', -0.05), ('hearing', 0.05), ('insured', -0.05), ('record', 0.04)]
#
# Topic 7
# [('city', -0.29), ('claimant', 0.28), ('ordinance', -0.27), ('respondent', -0.26), ('board', -0.19), ('published', 0.15), ('street', -0.14), ('policy', 0.13), ('insurance', 0.13), ('tax', -0.13), ('gun', -0.12), ('assessment', -0.12), ('railroad', -0.1), ('full', 0.1), ('plea', 0.1), ('improvement', -0.1), ('motion', 0.09), ('justice', 0.09), ('opinion', 0.09), ('public', -0.09), ('village', -0.09), ('robbery', -0.09), ('county', -0.09), ('coverage', 0.09), ('insured', 0.08), ('chicago', -0.08), ('town', -0.08), ('weapon', -0.08), ('petitioner', -0.08), ('presiding', 0.08), ('power', -0.07), ('district', -0.07), ('school', -0.07), ('council', -0.07), ('app', 0.07), ('3d', 0.07), ('shall', -0.07), ('commissioners', -0.07), ('zoning', -0.07), ('section', -0.06), ('mortgage', 0.06), ('train', -0.06), ('road', -0.06), ('cocaine', 0.06), ('note', 0.06), ('claim', 0.06), ('decree', 0.06), ('track', -0.06), ('special', -0.06), ('taxes', -0.06)]
#
# Topic 8
# [('published', -0.57), ('full', -0.34), ('opinion', -0.32), ('justice', -0.31), ('presiding', -0.26), ('claimant', -0.16), ('delivered', -0.15), ('policy', 0.14), ('insurance', 0.13), ('ordinance', -0.09), ('city', -0.09), ('coverage', 0.09), ('insured', 0.08), ('barnes', -0.08), ('board', -0.08), ('robbery', -0.07), ('burke', -0.07), ('lyons', -0.07), ('mcsurely', -0.06), ('3d', 0.06), ('app', 0.06), ('connor', -0.06), ('commission', -0.05), ('abrahamson', -0.05), ('county', -0.05), ('deed', 0.05), ('assessment', -0.05), ('wilson', -0.05), ('schwartz', -0.05), ('curiam', -0.04), ('mortgage', 0.04), ('scanlan', -0.04), ('petition', -0.04), ('seidenfeld', -0.04), ('arrest', -0.04), ('mccormick', -0.04), ('liability', 0.04), ('taylor', -0.04), ('matchett', -0.04), ('moran', -0.04), ('cocaine', 0.04), ('insurer', 0.04), ('agreement', 0.03), ('improvement', -0.03), ('estate', 0.03), ('child', 0.03), ('burman', -0.03), ('title', 0.03), ('tax', -0.03), ('commissioners', -0.03)]
#
# Topic 9
# [('claimant', 0.4), ('policy', -0.31), ('insurance', -0.29), ('published', -0.25), ('coverage', -0.2), ('gun', -0.2), ('respondent', -0.19), ('insured', -0.19), ('full', -0.15), ('plea', 0.15), ('opinion', -0.11), ('justice', -0.11), ('weapon', -0.1), ('company', -0.1), ('presiding', -0.1), ('petition', 0.1), ('commission', 0.1), ('liability', -0.08), ('motion', 0.08), ('insurer', -0.08), ('guilty', 0.08), ('child', -0.08), ('error', 0.07), ('app', -0.07), ('vehicle', -0.07), ('appeal', 0.06), ('uninsured', -0.06), ('county', 0.06), ('3d', -0.06), ('policies', -0.06), ('motorist', -0.06), ('children', -0.06), ('hearing', 0.06), ('record', 0.06), ('firearm', -0.06), ('marriage', -0.06), ('sentencing', 0.06), ('jury', 0.05), ('writ', 0.05), ('delivered', -0.05), ('jurisdiction', 0.05), ('car', -0.05), ('mutual', -0.05), ('industrial', 0.05), ('farm', -0.05), ('judge', 0.05), ('automobile', -0.05), ('circuit', 0.05), ('underinsured', -0.05), ('petitioner', -0.04)]
#
# set()
# c:\users\carle\appdata\local\programs\python\python39\lib\site-packages\ipykernel\ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
